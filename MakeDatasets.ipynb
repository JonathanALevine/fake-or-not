# %%
# %reset -f

# %%
#!/usr/bin/env python3
import pandas as pd
from tqdm import tqdm
import sys
from PIL import Image
import os

# %%
train_real_dir = '/home/jonathan/Desktop/real-vs-fake/train/real/'
train_fake_dir = '/home/jonathan/Desktop/real-vs-fake/train/fake/'
test_real_dir = '/home/jonathan/Desktop/real-vs-fake/test/real/'
test_fake_dir = '/home/jonathan/Desktop/real-vs-fake/test/fake/'
val_real_dir = '/home/jonathan/Desktop/real-vs-fake/val/real/'
val_fake_dir = '/home/jonathan/Desktop/real-vs-fake/val/fake/'

# %%
Image.open('/home/jonathan/Desktop/real-vs-fake/train/real/00000.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F4EFEF37340>
